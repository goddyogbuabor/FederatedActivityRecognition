# %%
import pandas as pd
import numpy as np

# %%
dataDir ='../FedAnalysis/Client1/'
COLUMNS = ['activity','position', 'xAxis', 'yAxis', 'zAxis', 'timestamp','time']
data = pd.read_csv(dataDir+'client1.csv', header=None, names=COLUMNS, 
                   index_col='timestamp', parse_dates=True)

# %%
#convert timestamp to datetime
data.index = pd.to_datetime(data.index, unit='s')

# %% [markdown]
# # Calculate Magnitude¶

# %%
import math

def magnitude(activity):
    x2 = activity['xAxis'] * activity['xAxis']
    y2 = activity['yAxis'] * activity['yAxis']
    z2 = activity['zAxis'] * activity['zAxis']
    m2 = x2 + y2 + z2
    m = m2.apply(lambda x: math.sqrt(x))
    return m

# %% [markdown]
# # FEATURE EXTRACTION

# %%
interval ='4s'

# %%
# Mean value
def mean_val(df):
    return df.resample(interval).mean()

# %%
#Standard Deviation value
def std_val(df):
    return df.resample(interval).std()

# %%
#Minimum Value
def min_val(df):
    return df.resample(interval).min()

# %%
# Maximum Value
def max_val(df):
    return df.resample(interval).max()

# %%
def var_val(df):
    return df.resample(interval).var()

# %%
# standard error of the mean of groups
def sem_val(df):
    return df.resample(interval).sem()

# %%
# median Value
def median_val(df):
    return df.resample(interval).median()

# %%
# get labels
def label_val(df):
    return df.resample(interval).min()

# %%
#Extract Feature for Algorithm Training
def trainData():

    #get class label for each activity
    data['magnitude'] = magnitude(data)
    CLASS= data['activity']
    train = data[['xAxis','yAxis','zAxis','magnitude']]

    features = pd.concat([mean_val(train),std_val(train),min_val(train),max_val(train),var_val(train),
                  sem_val(train),median_val(train),label_val(CLASS)],axis=1)
    #drop nan values
    features.dropna(inplace=True)
    
    columns = ['xmean', 'ymean', 'zmean','mmean','xstd', 'ystd','zstd','mstd','xmin','ymin','zmin','mmin',
           'xmax','ymax','zmax','mmax','xvar','yvar','zvar','mvar','xsem','ysem','zsem','msem',
           'xmedian','ymedian','zmedian','mmedian',"Activity"]

    #features = train
    features.columns = columns
    return features.to_csv(dataDir+'TrainData.csv', index=None)

# %%
trainData()

# %%
features = pd.read_csv(dataDir+'TrainData.csv') 
features.head(500)
# Out:
#         xmean     ymean     zmean      mmean      xstd      ystd      zstd  \
# 0   -1.771591  3.096146  8.803450   9.518092  0.360324  0.451487  0.579275
# 1   -1.726770  4.961432  8.358194   9.938323  0.656386  0.799041  0.689553
# 2   -1.557775  3.827060  8.818479  10.035977  1.192968  1.866665  1.517256
# 3    0.241994  1.591558  9.697032   9.965041  1.279706  0.975793  1.110011
# 4    0.769137  1.319624  9.648250   9.995323  1.555440  1.405278  1.375935
# 5   -1.185657  2.148054  9.463417  10.096079  1.946089  1.561202  1.509850
# 6    1.579515  1.386841  9.136046   9.906842  2.168414  1.371473  3.093156
# 7   -1.715817  1.453101  9.201719  10.795518  5.166618  3.354015  1.924215
# 8   -2.592214  0.425474  2.280022  10.724159  5.548519  5.439877  6.963412
# 9   -6.944274  0.081558 -6.770731   9.718066  0.463549  0.352514  0.338346
# 10  -7.158340  0.186939 -6.547675   9.716070  0.324906  0.374954  0.335668
# 11  -7.123181 -0.156114 -6.565751   9.691472  0.168171  0.148424  0.124970
# 12  -7.271250 -0.239660 -6.398696   9.691862  0.136282  0.164815  0.134512
# 13  -7.367892 -0.158089 -6.289281   9.689789  0.112702  0.098924  0.099633
# 14  -7.499442 -0.238941 -6.139990   9.699334  0.188780  0.158853  0.289373
# 15  -7.499561 -0.298030 -6.126415   9.690724  0.151130  0.118272  0.261187
# 16  -7.542430 -0.333847 -6.072557   9.697985  0.256528  0.213785  0.410592
# 17  -8.406377  0.464942 -4.740878   9.773934  0.934453  0.816713  1.054743
# 18  -8.950998 -0.039025 -3.748159   9.707760  0.166576  0.175962  0.174212
# 19  -8.913804 -0.175770 -3.827682   9.704644  0.119812  0.098585  0.169888
# 20  -8.892233 -0.150188 -3.891152   9.707812  0.042911  0.051408  0.061034
# 21  -8.918671 -0.162806 -3.815154   9.710715  0.218428  0.237292  0.301540
# 22  -8.945181 -0.247315 -3.757425   9.708172  0.166850  0.104339  0.231979
# 23  -8.900217 -0.341880 -3.845327   9.701756  0.047166  0.040125  0.068287
# 24  -9.378770 -0.142240  0.043874   9.712622  0.663785  0.652046  2.393890
# 25  -8.568369 -1.625459 -4.195671   9.683751  0.197015  0.080508  0.279381
# 26  -8.646291 -1.634211 -4.040307   9.682830  0.041987  0.038521  0.050777
# 27  -8.673312 -1.631971 -3.999885   9.689840  0.041455  0.038312  0.050636
# 28  -8.874614 -0.300757 -3.910856   9.714835  0.210102  0.325215  0.328097
# 29  -9.236830  0.835736 -2.458366   9.596644  0.074469  0.139892  0.134855
# ..        ...       ...       ...        ...       ...       ...       ...
# 76   0.415597  2.116151  9.712462  10.326363  2.008449  2.024210  2.078578
# 77  -1.982698  1.160901  9.633549   9.922425  0.450285  0.402672  0.615248
# 78  -2.677268  1.541387  9.360192   9.867977  0.387382  0.258101  0.335441
# 79  -3.008434  1.678623  9.205574   9.947925  1.270034  0.911252  0.788359
# 80  -3.533650  1.680059  9.040446   9.855772  0.203506  0.213429  0.171273
# 81  -2.236711  0.771986  9.432855   9.952074  1.616405  1.401986  1.599007
# 82   2.396309  1.603122  9.743467  11.056855  3.683145  2.615392  3.013872
# 83   1.709723  3.145131  9.236471  10.189339  1.843836  1.423277  2.307825
# 84  -4.930631 -1.675235  5.013722  10.968855  4.740305  5.475185  5.738293
# 85  -9.806399  0.688716  0.741424  10.211608  3.536080  1.666547  2.333724
# 86  -9.658736  0.375961  0.650672  10.052332  1.975062  2.069040  1.886253
# 87  -9.613043 -0.560854  0.351457  10.069785  1.940666  1.918885  2.401740
# 88  -9.729389 -0.043407 -0.539821  10.135041  2.705201  1.955726  2.064437
# 89  -9.703867  0.481965 -0.613502  10.002926  2.628830  1.711998  1.619358
# 90  -9.607333  0.806152 -0.121123   9.995128  2.442565  2.104518  1.939247
# 91  -9.625732  0.699179  0.119375  10.030299  2.194886  2.254188  1.839273
# 92  -9.667798  0.255473 -0.069815  10.289966  2.462136  2.766391  2.434788
# 93  -9.813498  0.812365 -0.367235  10.224692  2.057248  1.855743  2.104810
# 94  -9.676118  0.560914 -0.741400  10.111569  2.973061  2.333479  1.659175
# 95  -9.756061  0.694570 -0.515699  10.273954  3.142683  2.083571  2.721439
# 96  -9.715826  0.856909 -0.014904  10.184311  3.504943  2.198457  2.173234
# 97  -9.499725  0.228550 -0.067624  10.028158  4.057726  1.834627  2.867968
# 98  -9.582613  0.811622  0.303501  10.113715  3.697019  1.722253  2.762275
# 99  -9.780649  0.948930  0.662344  10.172524  1.741181  1.623864  2.171245
# 100 -9.567122  0.824264  0.101430  10.094840  3.250420  1.894804  3.254715
# 101 -9.551620  0.419380  0.522104  10.219703  3.896610  2.243231  2.981317
# 102 -9.750039  0.920726  0.153815  10.242754  4.005564  1.724851  2.668717
# 103 -9.500887  1.155537  0.837599  10.168173  3.444985  2.161073  2.918026
# 104 -9.394117  1.432571  2.077999   9.951877  2.462579  1.375725  1.982156
# 105 -9.583141  0.678180  0.741214   9.913477  2.496645  1.545618  1.840446
#
#          mstd       xmin       ymin  ...       mvar      xsem      ysem  \
# 0    0.543998  -2.710236   1.608904  ...   0.295933  0.040036  0.050165
# 1    0.479420  -4.252102   2.777274  ...   0.229844  0.023207  0.028250
# 2    1.148957 -10.984597  -0.296881  ...   1.320102  0.042178  0.065997
# 3    1.067987  -2.691083  -1.829170  ...   1.140597  0.045244  0.034499
# 4    1.340522  -2.461239  -1.723825  ...   1.796999  0.054993  0.049684
# 5    1.463452  -5.468357  -4.462792  ...   2.141692  0.068805  0.055197
# 6    2.424407  -3.888184 -16.242264  ...   5.877749  0.076665  0.048489
# 7    3.846604 -31.584309 -10.333375  ...  14.796364  0.182668  0.118582
# 8    2.414569 -16.548721 -13.378799  ...   5.830143  0.196170  0.192329
# 9    0.291098  -9.030929  -0.967257  ...   0.084738  0.016389  0.012463
# 10   0.324521  -8.293514  -0.632069  ...   0.105314  0.011487  0.013257
# 11   0.119985  -7.671022  -0.574608  ...   0.014397  0.005946  0.005248
# 12   0.058182  -7.517793  -0.746991  ...   0.003385  0.004818  0.005827
# 13   0.079050  -7.728483  -1.312023  ...   0.006249  0.003985  0.003497
# 14   0.256179  -9.136273  -0.785298  ...   0.065627  0.006674  0.005616
# 15   0.245070  -8.590396  -0.900220  ...   0.060059  0.005343  0.004182
# 16   0.323435  -9.548077  -2.288857  ...   0.104610  0.009070  0.007558
# 17   0.692445 -11.903971  -2.882619  ...   0.479481  0.033038  0.028875
# 18   0.137680  -9.730036  -0.823605  ...   0.018956  0.005889  0.006221
# 19   0.103500  -9.433155  -0.976834  ...   0.010712  0.004236  0.003485
# 20   0.044886  -9.021352  -0.296881  ...   0.002015  0.001517  0.001818
# 21   0.146064 -10.888829  -2.135628  ...   0.021335  0.007821  0.008496
# 22   0.198886 -10.505757  -0.775721  ...   0.039556  0.005827  0.003644
# 23   0.041401  -9.107543  -0.478840  ...   0.001714  0.001668  0.001419
# 24   0.486819 -11.003751  -1.934515  ...   0.236993  0.023468  0.023053
# 25   0.104428  -8.877700  -1.934515  ...   0.010905  0.006966  0.002846
# 26   0.041197  -8.781932  -1.752556  ...   0.001697  0.001681  0.001542
# 27   0.038486  -8.801085  -1.742979  ...   0.001481  0.002232  0.002063
# 28   0.151957  -9.806650  -1.628057  ...   0.023091  0.009313  0.014415
# 29   0.087019  -9.414001   0.612916  ...   0.007572  0.013596  0.025541
# ..        ...        ...        ...  ...        ...       ...       ...
# 76   2.188872  -3.955221  -1.379060  ...   4.791163  0.071009  0.071567
# 77   0.610334  -3.552995  -0.143652  ...   0.372507  0.015920  0.014237
# 78   0.329817  -3.782839   0.689530  ...   0.108779  0.013696  0.009125
# 79   0.843658  -7.872135  -2.442086  ...   0.711759  0.044902  0.032218
# 80   0.137410  -4.625597   1.130063  ...   0.018881  0.007195  0.007546
# 81   1.631988  -5.908890  -3.141193  ...   2.663385  0.057149  0.049568
# 82   3.234021  -8.705317  -5.458780  ...  10.458891  0.130219  0.092468
# 83   2.247030  -4.252102   0.258574  ...   5.049143  0.065189  0.050320
# 84   4.150920 -24.602818 -16.002844  ...  17.230133  0.167595  0.193577
# 85   3.692044 -22.639572  -3.715801  ...  13.631189  0.125019  0.058921
# 86   2.130087 -15.801731  -6.110003  ...   4.537271  0.069829  0.073152
# 87   2.157326 -15.801731  -7.230489  ...   4.654055  0.068613  0.067843
# 88   2.762319 -16.558298  -6.196194  ...   7.630408  0.095643  0.069145
# 89   2.678166 -17.793707  -5.698200  ...   7.172572  0.092943  0.060528
# 90   2.685132 -16.424223  -2.873042  ...   7.209933  0.086358  0.074406
# 91   2.413175 -16.654066  -4.146757  ...   5.823413  0.077601  0.079698
# 92   2.698304 -15.485697 -10.639833  ...   7.280844  0.087050  0.097807
# 93   2.156888 -16.797720  -4.041412  ...   4.652167  0.072735  0.065610
# 94   3.045505 -16.692375  -5.085284  ...   9.275100  0.105114  0.082501
# 95   3.462207 -18.856733  -4.280833  ...  11.986878  0.111111  0.073665
# 96   3.638906 -22.840685  -6.157887  ...  13.241639  0.123918  0.077727
# 97   4.216756 -18.521544  -5.755661  ...  17.781028  0.143462  0.064864
# 98   3.813422 -18.703505  -3.801992  ...  14.542185  0.130709  0.060891
# 99   1.973538 -17.276560  -6.684611  ...   3.894854  0.061560  0.057412
# 100  3.879470 -17.966090  -4.922479  ...  15.050286  0.114920  0.066991
# 101  4.040731 -19.019539  -7.709330  ...  16.327509  0.137766  0.079310
# 102  4.141391 -20.207062  -3.658340  ...  17.151119  0.141618  0.060983
# 103  3.735118 -17.410635  -9.184157  ...  13.951107  0.121799  0.076405
# 104  2.731346 -15.715540  -0.699107  ...   7.460248  0.087065  0.048639
# 105  2.562947 -16.644490  -3.620033  ...   6.568695  0.104849  0.064910
#
#          zsem      msem    xmedian   ymedian   zmedian    mmedian  Activity
# 0    0.064364  0.060444  -1.790863  3.141193  8.935161   9.644496   Sitting
# 1    0.024379  0.016950  -1.704672  5.056554  8.360553   9.928128   Sitting
# 2    0.053643  0.040622  -1.455675  4.180276  8.710106   9.985064   Sitting
# 3    0.039245  0.037759   0.167594  1.628057  9.586384   9.947188   Sitting
# 4    0.048647  0.047395   0.790087  1.273715  9.768343   9.967823   Sitting
# 5    0.053381  0.051741  -1.225831  2.102109  9.471462   9.967998   Sitting
# 6    0.109360  0.085716   1.517924  1.584961  9.375694   9.885313   Sitting
# 7    0.068031  0.135998   0.038307  0.823605  9.749189   9.875799   Sitting
# 8    0.246194  0.085368  -2.858677  0.517148  5.181053  10.116966   Sitting
# 9    0.011962  0.010292  -6.924031  0.076614 -6.799533   9.684610   Sitting
# 10   0.011868  0.011474  -7.134721  0.105345 -6.569689   9.709739   Sitting
# 11   0.004418  0.004242  -7.105990 -0.143652 -6.569689   9.694252   Sitting
# 12   0.004756  0.002057  -7.307104 -0.191536 -6.368576   9.692911   Sitting
# 13   0.003523  0.002795  -7.374141 -0.153229 -6.282385   9.694444   Sitting
# 14   0.010231  0.009057  -7.489063 -0.248997 -6.148310   9.691955   Sitting
# 15   0.009234  0.008665  -7.508216 -0.306458 -6.129156   9.690060   Sitting
# 16   0.014517  0.011435  -7.536947 -0.335188 -6.071695   9.689674   Sitting
# 17   0.037291  0.024482  -8.552089  0.359130 -4.577713   9.742866   Sitting
# 18   0.006159  0.004868  -8.944737 -0.009577 -3.715801   9.705351   Sitting
# 19   0.006006  0.003659  -8.906430 -0.172383 -3.840300   9.701327   Sitting
# 20   0.002158  0.001587  -8.896853 -0.153229 -3.888184   9.706725   Sitting
# 21   0.010797  0.005230  -8.916007 -0.172383 -3.840300   9.703288   Sitting
# 22   0.008101  0.006945  -8.944737 -0.248997 -3.744531   9.702496   Sitting
# 23   0.002414  0.001464  -8.896853 -0.344765 -3.849876   9.701631   Sitting
# 24   0.084637  0.017212  -9.471462 -0.076614  1.273715   9.740450   Sitting
# 25   0.009878  0.003692  -8.609549 -1.628057 -4.108450   9.686137   Sitting
# 26   0.002033  0.001649  -8.647857 -1.637634 -4.041412   9.683329   Sitting
# 27   0.002726  0.002072  -8.676587 -1.637634 -3.993528   9.686665   Sitting
# 28   0.014543  0.006735  -8.820239 -0.344765 -4.031836   9.703347   Sitting
# 29   0.024621  0.015887  -9.212888  0.876278 -2.446874   9.576684   Sitting
# ..        ...       ...        ...       ...       ...        ...       ...
# 76   0.073489  0.077388   0.344765  1.900996  9.538500   9.930100   Walking
# 77   0.021752  0.021579  -1.905785  1.101333  9.624691   9.870420   Walking
# 78   0.011860  0.011661  -2.719813  1.513135  9.366117   9.874856   Walking
# 79   0.027873  0.029828  -3.107674  1.589750  9.299079   9.883997   Walking
# 80   0.006055  0.004858  -3.533842  1.656788  9.040505   9.850906   Walking
# 81   0.056533  0.057699  -2.375048  1.125275  9.208099   9.912323   Walking
# 82   0.106556  0.114340   1.728614  1.546654  9.481039  10.483511   Walking
# 83   0.081594  0.079445   1.920150  3.026271  9.045293  10.103182   Walking
# 84   0.202879  0.146757  -4.362236 -1.398214  5.300763  10.558095   Walking
# 85   0.082510  0.130533  -9.399636  0.445322  0.282516   9.808729   Walking
# 86   0.066689  0.075310  -9.725248  0.426168  0.823605   9.947433   Walking
# 87   0.084914  0.076273  -9.485827 -0.421380  0.478840   9.920114   Walking
# 88   0.072989  0.097663  -9.701306 -0.071826 -0.488417  10.263406   Walking
# 89   0.057253  0.094687  -9.667787  0.383072 -0.656011   9.951579   Walking
# 90   0.068563  0.094934  -9.500193  0.378284 -0.239420   9.772640   Walking
# 91   0.065028  0.085319  -9.548077  0.349553  0.335188   9.857612   Walking
# 92   0.086083  0.095399  -9.935937  0.277727 -0.148441  10.601070   Walking
# 93   0.074416  0.076258  -9.691729  0.584185 -0.047884  10.070531   Walking
# 94   0.058661  0.107675  -9.543288  0.497994 -0.550666   9.883534   Walking
# 95   0.096217  0.122408  -9.825804  0.435745 -0.253785  10.236177   Walking
# 96   0.076835  0.128655  -9.763554  1.005565 -0.052672  10.198195   Walking
# 97   0.101398  0.149085  -9.686940  0.555455 -0.550666  10.217484   Walking
# 98   0.097661  0.134825 -10.103531  0.957681 -0.325611  10.512885   Walking
# 99   0.076765  0.069775  -9.749189  1.000776  0.579397  10.006702   Walking
# 100  0.115072  0.137160  -9.854534  0.761356 -0.469264  10.137605   Walking
# 101  0.105405  0.142861  -9.974244  0.488417  0.536301  10.830929   Walking
# 102  0.094353  0.146420 -10.338164  0.976834 -0.339977  10.624230   Walking
# 103  0.103168  0.132056  -9.385271  1.211466  0.603339   9.898364   Walking
# 104  0.070080  0.096568  -9.342175  1.197101  2.116474   9.904157   Walking
# 105  0.077291  0.107634  -9.557653  0.622492  0.708684   9.857261   Walking
#
# [106 rows x 29 columns]
